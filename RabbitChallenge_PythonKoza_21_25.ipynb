# %% [markdown]
# #PY21

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), color= 'green')

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.cos(x), linestyle= '-.')

# %%
x = np.linspace(0, 10, 40)
plt.plot(x, np.cos(x), marker='o', linestyle='')

# %%
x = np.linspace(0, 10, 40)
plt.plot(x, np.cos(x), marker='o', linestyle='-')

# %%
plt.scatter(
    np.random.randn(100),
    np.random.randn(100),
    c = np.random.randn(100),
    s = np.random.randn(100) * 200,
    alpha= 0.55
)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
def f(x, y):
  return np.cos(x) ** 10 + np.sin(10 + y * x) * np.sin(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
plt.contour(X, Y, f(X, Y))

# %%
def f(x, y):
  return np.cos(x) ** 10 + np.sin(10 + y * x) * np.sin(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
plt.contourf(X, Y, f(X, Y), 20, cmap='RdGy')

# %%
plt.hist(np.random.randn(1000))
# Out:
# (array([  3.,  23.,  60., 142., 196., 264., 177.,  94.,  30.,  11.]),
#  array([-3.16621606, -2.55986293, -1.9535098 , -1.34715667, -0.74080354,
#         -0.13445041,  0.47190272,  1.07825585,  1.68460898,  2.29096211,
#          2.89731524]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.random.randn(1000), bins=50)
# Out:
# (array([ 1.,  0.,  0.,  4.,  2.,  1.,  2.,  4., 10., 11.,  4., 12., 16.,
#         20., 23., 37., 27., 32., 39., 57., 53., 37., 52., 42., 56., 50.,
#         44., 58., 49., 49., 38., 23., 25., 36., 22., 21.,  9.,  7.,  8.,
#          2.,  5.,  5.,  4.,  2.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([-3.21160511, -3.0773632 , -2.94312129, -2.80887939, -2.67463748,
#         -2.54039558, -2.40615367, -2.27191176, -2.13766986, -2.00342795,
#         -1.86918605, -1.73494414, -1.60070223, -1.46646033, -1.33221842,
#         -1.19797652, -1.06373461, -0.9294927 , -0.7952508 , -0.66100889,
#         -0.52676698, -0.39252508, -0.25828317, -0.12404127,  0.01020064,
#          0.14444255,  0.27868445,  0.41292636,  0.54716826,  0.68141017,
#          0.81565208,  0.94989398,  1.08413589,  1.21837779,  1.3526197 ,
#          1.48686161,  1.62110351,  1.75534542,  1.88958732,  2.02382923,
#          2.15807114,  2.29231304,  2.42655495,  2.56079686,  2.69503876,
#          2.82928067,  2.96352257,  3.09776448,  3.23200639,  3.36624829,
#          3.5004902 ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #PY22

# %%
x = np.linspace(0, 10, 1000)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(x, np.sin(x))

# %%
#凡例
x = np.linspace(0, 10, 1000)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(x, np.sin(x), label='sin(x)')
ax.plot(x, np.cos(x), label='cos(x)')

fig.legend()

# %%
#グラフのデザイン
plt.style.use('seaborn-bright')

x = np.linspace(0, 10, 1000)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(x, np.sin(x), label="sin(x)")
ax.plot(x, np.cos(x), label="cos(x)")

fig.legend()

# %%
#グラフのデザイン
plt.style.use('dark_background')

x = np.linspace(0, 10, 1000)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(x, np.sin(x), label="sin(x)")
ax.plot(x, np.cos(x), label="cos(x)")

fig.legend()

# %%
#グラフのデザイン
plt.style.use('ggplot')

x = np.linspace(0, 10, 1000)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(x, np.sin(x), label="sin(x)")
ax.plot(x, np.cos(x), label="cos(x)")

fig.legend()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# #PY23

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('seaborn')

# %%
iris = sns.load_dataset('iris')
g = sns.PairGrid(iris, hue='species')
g.map(plt.scatter);

# %%
plt.style.use('dark_background')
iris = sns.load_dataset('iris')
g = sns.PairGrid(iris, hue='species')
g.map(plt.scatter);

# %%
import pandas as pd
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('seaborn')

dataset = load_boston()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['MEDV'] = dataset.target

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677083   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(df[['RM','LSTAT','MEDV']])

# %%
#distplot()関数　・・・　ヒストグラムと密度関数を得られる
sns.distplot(df['MEDV'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#jointplot() ・・・ 2つの値の分布について相関を得られる
x, y = df['MEDV'], df['LSTAT']
sns.jointplot(x, y, alpha=0.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#jointplot()の別種の表示方式
sns.jointplot(df['MEDV'], df['LSTAT'], kind='kde')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #PY24

# %%
#scikit-learn
